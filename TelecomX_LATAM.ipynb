# %% [markdown]
# <a href="https://colab.research.google.com/github/mandarina125/TelecomX_LATAM_1/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import requests
import pandas as pd

url = "https://raw.githubusercontent.com/sthemonica/alura-voz/refs/heads/main/Dados/Telco-Customer-Churn.json"

solicitud = requests.get(url)
data = solicitud.json()

df = pd.DataFrame(data)

df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %% [markdown]
# #🔧 Transformación

# %%
import pandas as pd
df_normalizado = pd.json_normalize(data )
df_normalizado
# Out:
#       customerID Churn customer.gender  customer.SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer.Partner customer.Dependents  customer.tenure phone.PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %% [markdown]
# Revisar la estructura del DataFrame

# %%
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer.gender            7267 non-null   object
#  3   customer.SeniorCitizen     7267 non-null   int64
#  4   customer.Partner           7267 non-null   object
#  5   customer.Dependents        7267 non-null   object
#  6   customer.tenure            7267 non-null   int64
#  7   phone.PhoneService         7267 non-null   object
#  8   phone.MultipleLines        7267 non-null   object
#  9   internet.InternetService   7267 non-null   object
#  10  internet.OnlineSecurity    7267 non-null   object
#  11  internet.OnlineBackup      7267 non-null   object
#  12  internet.DeviceProtection  7267 non-null   object
# ...

# %% [markdown]
# Verificar valores nulos

# %%
df_normalizado.isnull().sum()
# Out:
# customerID                   0
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# account.Charges.Total        0
# dtype: int64

# %% [markdown]
# Revisar duplicados (por ID de cliente)

# %%
df_normalizado.duplicated(subset='customerID').sum()
# Out:
# np.int64(0)

# %% [markdown]
#  Convertir columnas numéricas al tipo correcto

# %%
df_normalizado['account.Charges.Total'] = pd.to_numeric(df_normalizado['account.Charges.Total'], errors='coerce')
df_normalizado['account.Charges.Monthly'] = pd.to_numeric(df_normalizado['account.Charges.Monthly'], errors='coerce')

# %%
df_normalizado.isnull().sum()
# Out:
# customerID                    0
# Churn                         0
# customer.gender               0
# customer.SeniorCitizen        0
# customer.Partner              0
# customer.Dependents           0
# customer.tenure               0
# phone.PhoneService            0
# phone.MultipleLines           0
# internet.InternetService      0
# internet.OnlineSecurity       0
# internet.OnlineBackup         0
# internet.DeviceProtection     0
# internet.TechSupport          0
# internet.StreamingTV          0
# internet.StreamingMovies      0
# account.Contract              0
# account.PaperlessBilling      0
# account.PaymentMethod         0
# account.Charges.Monthly       0
# account.Charges.Total        11
# dtype: int64

# %%
df_normalizado = df_normalizado.dropna(subset=['account.Charges.Total'])

# %% [markdown]
# Unificar categorías

# %%
df_normalizado = df_normalizado[df_normalizado['Churn'].isin(['Yes', 'No'])]

# %% [markdown]
# Ver valores únicos en variables categóricas

# %%
df_normalizado['Churn'].unique()
df_normalizado['account.PaymentMethod'].unique()
df_normalizado['customer.gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df_normalizado['Churn'] = df_normalizado['Churn'].astype('category')
df_normalizado['account.Contract'] = df_normalizado['account.Contract'].astype('category')

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# Análisis Descriptivo

# %%
# Ver columnas numéricas del DataFrame
df_normalizado.select_dtypes(include='number').columns
# Out:
# Index(['customer.SeniorCitizen', 'customer.tenure', 'account.Charges.Monthly',
#        'account.Charges.Total'],
#       dtype='object')

# %%
# Estadísticas descriptivas básicas
df_normalizado.describe()
# Out:
#        customer.SeniorCitizen  customer.tenure  account.Charges.Monthly  \
# count             7032.000000      7032.000000              7032.000000
# mean                 0.162400        32.421786                64.798208
# std                  0.368844        24.545260                30.085974
# min                  0.000000         1.000000                18.250000
# 25%                  0.000000         9.000000                35.587500
# 50%                  0.000000        29.000000                70.350000
# 75%                  0.000000        55.000000                89.862500
# max                  1.000000        72.000000               118.750000
#
#        account.Charges.Total
# count            7032.000000
# mean             2283.300441
# std              2266.771362
# min                18.800000
# 25%               401.450000
# 50%              1397.475000
# 75%              3794.737500
# max              8684.800000

# %%
# Mediana por columna numérica (no incluida en describe por defecto)
df_normalizado.median(numeric_only=True)
# Out:
# customer.SeniorCitizen        0.000
# customer.tenure              29.000
# account.Charges.Monthly      70.350
# account.Charges.Total      1397.475
# dtype: float64

# %%
# Desviación estándar por columna
df_normalizado.std(numeric_only=True)
# Out:
# customer.SeniorCitizen        0.368844
# customer.tenure              24.545260
# account.Charges.Monthly      30.085974
# account.Charges.Total      2266.771362
# dtype: float64

# %%
# Valores únicos por algunas columnas clave
print(df_normalizado['Churn'].value_counts())
print(df_normalizado['account.Contract'].value_counts())
print(df_normalizado['account.PaymentMethod'].value_counts())
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64
# account.Contract
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: count, dtype: int64
# account.PaymentMethod
# Electronic check             2365
# Mailed check                 1604
# Bank transfer (automatic)    1542
# Credit card (automatic)      1521
# Name: count, dtype: int64

# %%
# Seleccionar solo las columnas numéricas
numeric_cols = df_normalizado.select_dtypes(include='number')

# Crear resumen estadístico transpuesto para mejor lectura
summary = numeric_cols.describe().T

# Agregar la mediana manualmente
summary["median"] = numeric_cols.median()

# Reorganizar columnas
summary = summary[["count", "mean", "median", "std", "min", "25%", "50%", "75%", "max"]]

# Mostrar resumen
summary
# Out:
#                           count         mean    median          std    min  \
# customer.SeniorCitizen   7032.0     0.162400     0.000     0.368844   0.00
# customer.tenure          7032.0    32.421786    29.000    24.545260   1.00
# account.Charges.Monthly  7032.0    64.798208    70.350    30.085974  18.25
# account.Charges.Total    7032.0  2283.300441  1397.475  2266.771362  18.80
#
#                               25%       50%        75%      max
# customer.SeniorCitizen     0.0000     0.000     0.0000     1.00
# customer.tenure            9.0000    29.000    55.0000    72.00
# account.Charges.Monthly   35.5875    70.350    89.8625   118.75
# account.Charges.Total    401.4500  1397.475  3794.7375  8684.80

# %% [markdown]
# **Distribución de evasión**

# %%
df_normalizado['Churn'].value_counts()
# Out:
# Churn
# No     5163
# Yes    1869
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gráfico de barras
sns.countplot(data=df_normalizado, x='Churn', palette='pastel')
plt.title("Distribución de Evasión de Clientes")
plt.xlabel("¿Cliente se dio de baja?")
plt.ylabel("Cantidad de Clientes")
plt.show()
# Out:
# /tmp/ipython-input-1496784754.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_normalizado, x='Churn', palette='pastel')

# %%
# Pie chart
labels = df_normalizado['Churn'].value_counts().index
sizes = df_normalizado['Churn'].value_counts().values

plt.figure(figsize=(6,6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#ff9999'])
plt.title("Proporción de Clientes que se Dieron de Baja vs. Retenidos")
plt.axis('equal')  # Para que el círculo esté proporcionado
plt.show()

# %% [markdown]
# 73.4% de los clientes permanecen activos con la empresa.
#
# 26.6% de los clientes se han dado de baja.
#
# Esta proporción revela que aproximadamente 1 de cada 4 clientes cancela el servicio, lo cual representa una tasa de evasión moderadamente alta. Esta situación podría tener un impacto negativo en la rentabilidad y sostenibilidad del negocio, especialmente si no se identifican y abordan las causas detrás de estas cancelaciones.

# %% [markdown]
# **Recuento de evasión por variables categóricas**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Lista de variables categóricas a analizar
categorical_vars = [
    'customer.gender',
    'account.Contract',
    'account.PaymentMethod',
    'internet.InternetService',
    'phone.MultipleLines',
    'customer.SeniorCitizen'
]

# Crear gráficos uno por uno
for var in categorical_vars:
    plt.figure(figsize=(6,4))
    sns.countplot(data=df_normalizado, x=var, hue='Churn', palette='pastel')
    plt.title(f'Evasión de Clientes según {var}')
    plt.xticks(rotation=45)
    plt.xlabel(var)
    plt.ylabel('Cantidad de Clientes')
    plt.legend(title='Churn')
    plt.tight_layout()
    plt.show()

# %% [markdown]
#  1. Género del cliente (customer.gender)
#
#
# *   Hallazgo: La cantidad de hombres y mujeres que se han retirado es  prácticamente la misma.
# *  Interpretación: Esto sugiere que el género no influye directamente en la decisión de abandonar el servicio.

# %% [markdown]
#  2. Tipo de contrato (account.Contract)
#
#
# *   Hallazgo: Los clientes con contrato mensual presentan la mayor tasa de evasión (aproximadamente 1500 cancelaciones).
# *  Interpretación: Los contratos mensuales, al no tener compromisos a largo plazo, facilitan que los clientes cancelen el servicio en cualquier momento. Por tanto, el tipo de contrato es un fuerte predictor de churn, y la empresa podría enfocar sus estrategias de retención en estos usuarios.

# %% [markdown]
#  3. Método de pago (account.PaymentMethod)
#
#
# *   Hallazgo: El método "Electronic check" (cheque electrónico) tiene una alta proporción de cancelaciones.
# *   Interpretación: Esto podría indicar que los clientes que pagan con métodos menos automatizados (como cheques electrónicos) tienen una menor fidelidad o enfrentan más fricciones al pagar. Aunque el medio de pago en sí mismo podría no ser la causa. Esto podria ayudar como indicador para retener a esos clientes.

# %% [markdown]
# Múltiples líneas telefónicas (phone.MultipleLines)
#
#
# *    Hallazgo: Tanto quienes tienen una sola línea como quienes tienen múltiples abandonan el servicio.
# *   Interpretación: Si las tasas de churn son similares entre ambos grupos, entonces tener múltiples líneas no parece ser un factor decisivo. Sin embargo, se podria profundizar observando el porcentaje (no solo la cantidad) para ver si hay diferencia relativa.

# %% [markdown]
# Ciudadano Senior (customer.SeniorCitizen)
# Dato: Esta columna indica si el cliente es adulto mayor:
#
# 0: No es senior (menor de 65)
#
# 1: Sí es senior (mayor de 65)

# %% [markdown]
# #📄Informe final

# %%
from IPython.display import Markdown, display

sections = {
    "Introducción": """
## Introducción

Telecom X enfrenta una creciente tasa de cancelación de clientes (churn), lo cual impacta directamente en la rentabilidad y sostenibilidad del negocio.
Este análisis tiene como objetivo identificar los factores que más contribuyen a la pérdida de clientes, permitiendo así diseñar estrategias efectivas de retención.

El análisis se realizó con un conjunto de datos estructurados en formato JSON, conteniendo información de clientes, servicios contratados, métodos de pago y estado de cancelación.
""",

    "Limpieza y Tratamiento de Datos": """
## Limpieza y Tratamiento de Datos

Se aplicaron los siguientes pasos:

- Extracción de datos desde una fuente remota (o carga local)
- Normalización de estructuras anidadas con `pd.json_normalize`
- Conversión de columnas numéricas como `account.Charges.Total`
- Eliminación de duplicados por `customerID`
- Conversión de variables como `SeniorCitizen` a formato legible
- Identificación y tratamiento de valores nulos
""",

    "Análisis Exploratorio de Datos (EDA)": """
## Análisis Exploratorio de Datos (EDA)

Se analizaron diversas variables para entender los patrones de cancelación:

- **Distribución general de churn**: 26.6% de los clientes han cancelado.
- **Por contrato**: El contrato mensual tiene la mayor proporción de cancelación (~1500).
- **Por método de pago**: Cheque electrónico está asociado a mayor churn.
- **Por tipo de servicio de internet**: Fibra óptica tiene más cancelaciones.
- **Género**: No se observa diferencia significativa entre hombres y mujeres.
- **SeniorCitizen**: Aún por explorar con mayor profundidad.

Los análisis fueron acompañados de gráficos como `countplot` y `pie chart` para facilitar la visualización.
""",

    "Conclusiones e Insights": """
## Conclusiones e Insights

- El **contrato mensual** representa el mayor riesgo de cancelación.
- Clientes que usan **cheque electrónico** tienen una mayor tasa de churn.
- El uso de **fibra óptica** puede estar relacionado con mayores expectativas no satisfechas.
- El género **no parece influir significativamente** en la decisión de cancelar.
- La segmentación por características permite identificar perfiles de riesgo.

Estos hallazgos permiten enfocar las estrategias de retención en segmentos vulnerables.
""",

    "Recomendaciones": """
## Recomendaciones

- Incentivar el cambio de contrato mensual a anual mediante descuentos u ofertas exclusivas.
- Promover métodos de pago más automáticos (como débito automático o tarjeta).
- Realizar encuestas de satisfacción a usuarios de fibra óptica para mejorar el servicio.
- Desarrollar alertas internas que identifiquen usuarios con alto riesgo de churn basado en su perfil.
- Continuar con un modelo predictivo usando estos datos como base.
"""
}

# Mostrar cada sección como Markdown
for title, content in sections.items():
    display(Markdown(content))
# Out:
# ## Introducción
#
# Telecom X enfrenta una creciente tasa de cancelación de clientes (churn), lo cual impacta directamente en la rentabilidad y sostenibilidad del negocio.
# Este análisis tiene como objetivo identificar los factores que más contribuyen a la pérdida de clientes, permitiendo así diseñar estrategias efectivas de retención.
#
# El análisis se realizó con un conjunto de datos estructurados en formato JSON, conteniendo información de clientes, servicios contratados, métodos de pago y estado de cancelación.
# ## Limpieza y Tratamiento de Datos
#
# Se aplicaron los siguientes pasos:
#
# - Extracción de datos desde una fuente remota (o carga local)
# - Normalización de estructuras anidadas con `pd.json_normalize`
# - Conversión de columnas numéricas como `account.Charges.Total`
# - Eliminación de duplicados por `customerID`
# - Conversión de variables como `SeniorCitizen` a formato legible
# - Identificación y tratamiento de valores nulos
# ...
